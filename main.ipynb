# %% [markdown]
# # Explainable AI: SHAP, LIME ... for the Houce price prediction problem
#
#
# Contributors: Oleksandra Chernenko (131239) and Bruno Gomes (number)
# Workload: ??/??
#
# Oleksandra:
# - something
#
# Bruno:
# - something

# %% [markdown]
# ## Overview of the problem (From EDA)

# %% [markdown]
# ## EDA

# %% [markdown]
# ## Modeling

# %% [markdown]
# ## XAI

# %% [markdown]
# ### SHAP

# %% [markdown]
# ### LIME

# %% [markdown]
# ## Conclusions
